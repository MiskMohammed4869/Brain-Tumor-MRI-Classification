# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from pathlib import Path
from tensorflow.keras import layers, Sequential, callbacks, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import image_dataset_from_directory

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix

# %%
input_root = Path("/kaggle/input")

training_dirs = list(input_root.rglob("Training"))
testing_dirs = list(input_root.rglob("Testing"))

train_path = str(training_dirs[0])
test_path = str(testing_dirs[0])

print("Train path:", train_path)
print("Test path:", test_path)
# Out:
# Train path: /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training
# Test path: /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing

# %%
batch_size = 32
img_height = 225
img_width = 225
seed = 123

train_ds = image_dataset_from_directory(
    train_path,
    labels="inferred",
    label_mode="categorical",
    validation_split=0.2,
    subset="training",
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

val_ds = image_dataset_from_directory(
    train_path,
    labels="inferred",
    label_mode="categorical",
    validation_split=0.2,
    subset="validation",
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

test_ds = image_dataset_from_directory(
    test_path,
    labels="inferred",
    label_mode="categorical",
    image_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=False
)

class_names = train_ds.class_names
num_classes = len(class_names)

print(class_names)
# Out:
# Found 5600 files belonging to 4 classes.
# Using 4480 files for training.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784177232.186694      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1784177232.189534      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 5600 files belonging to 4 classes.
# Using 1120 files for validation.
# Found 1600 files belonging to 4 classes.
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %%
img_augmentation = Sequential([
    layers.RandomRotation(15/360),
    layers.RandomTranslation(0.05, 0.05),
    layers.RandomFlip("horizontal"),
    layers.RandomContrast(0.1),
], name="img_augmentation")

model = Sequential([
    layers.Input(shape=(img_height, img_width, 3)),

    img_augmentation,
    layers.Rescaling(1./255),

    layers.Conv2D(32, 3, padding="same", activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.Conv2D(64, 3, padding="same", activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.Conv2D(128, 3, padding="same", activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.Conv2D(256, 3, padding="same", activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation="softmax")
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ img_augmentation (Sequential)   │ (None, 225, 225, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 225, 225, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 225, 225, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 225, 225, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 423,748 (1.62 MB)
#  Trainable params: 422,788 (1.61 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

early_stop = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=7,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.2,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

checkpoint = callbacks.ModelCheckpoint(
    "best_custom_cnn.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[early_stop, reduce_lr, checkpoint]
)
# Out:
# Epoch 1/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5464 - loss: 1.0849
# Epoch 1: val_loss improved from None to 1.52647, saving model to best_custom_cnn.keras
#
# Epoch 1: finished saving model to best_custom_cnn.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 27s 134ms/step - accuracy: 0.6295 - loss: 0.9082 - val_accuracy: 0.2223 - val_loss: 1.5265 - learning_rate: 1.0000e-04
# Epoch 2/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7376 - loss: 0.6944
# Epoch 2: val_loss did not improve from 1.52647
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 18s 128ms/step - accuracy: 0.7408 - loss: 0.6760 - val_accuracy: 0.3107 - val_loss: 1.6493 - learning_rate: 1.0000e-04
# Epoch 3/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7857 - loss: 0.6008
# Epoch 3: val_loss improved from 1.52647 to 1.23730, saving model to best_custom_cnn.keras
#
# Epoch 3: finished saving model to best_custom_cnn.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 18s 130ms/step - accuracy: 0.7752 - loss: 0.6027 - val_accuracy: 0.5036 - val_loss: 1.2373 - learning_rate: 1.0000e-04
# Epoch 4/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7907 - loss: 0.5562
# Epoch 4: val_loss improved from 1.23730 to 0.84326, saving model to best_custom_cnn.keras
#
# Epoch 4: finished saving model to best_custom_cnn.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 19s 132ms/step - accuracy: 0.7926 - loss: 0.5626 - val_accuracy: 0.6393 - val_loss: 0.8433 - learning_rate: 1.0000e-04
# Epoch 5/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8189 - loss: 0.4944
# Epoch 5: val_loss did not improve from 0.84326
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 19s 135ms/step - accuracy: 0.8183 - loss: 0.4947 - val_accuracy: 0.6518 - val_loss: 0.9344 - learning_rate: 1.0000e-04
# Epoch 6/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8374 - loss: 0.4557
# Epoch 6: val_loss improved from 0.84326 to 0.77338, saving model to best_custom_cnn.keras
#
# Epoch 6: finished saving model to best_custom_cnn.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 0.8368 - loss: 0.4480 - val_accuracy: 0.7196 - val_loss: 0.7734 - learning_rate: 1.0000e-04
# Epoch 7/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8341 - loss: 0.4354
# Epoch 7: val_loss improved from 0.77338 to 0.47916, saving model to best_custom_cnn.keras
#
# Epoch 7: finished saving model to best_custom_cnn.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 20s 140ms/step - accuracy: 0.8337 - loss: 0.4391 - val_accuracy: 0.8241 - val_loss: 0.4792 - learning_rate: 1.0000e-04
# Epoch 8/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8435 - loss: 0.4201
# Epoch 8: val_loss improved from 0.47916 to 0.33286, saving model to best_custom_cnn.keras
#
# Epoch 8: finished saving model to best_custom_cnn.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 19s 136ms/step - accuracy: 0.8400 - loss: 0.4192 - val_accuracy: 0.8991 - val_loss: 0.3329 - learning_rate: 1.0000e-04
# Epoch 9/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8507 - loss: 0.3946
# Epoch 9: val_loss did not improve from 0.33286
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 19s 135ms/step - accuracy: 0.8509 - loss: 0.3983 - val_accuracy: 0.8527 - val_loss: 0.3675 - learning_rate: 1.0000e-04
# Epoch 10/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8585 - loss: 0.3822
# Epoch 10: val_loss did not improve from 0.33286
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 19s 136ms/step - accuracy: 0.8545 - loss: 0.3894 - val_accuracy: 0.7554 - val_loss: 0.5307 - learning_rate: 1.0000e-04
# Epoch 11/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8593 - loss: 0.3761
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 11: val_loss did not improve from 0.33286
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 19s 137ms/step - accuracy: 0.8603 - loss: 0.3715 - val_accuracy: 0.8482 - val_loss: 0.4193 - learning_rate: 1.0000e-04
# Epoch 12/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8782 - loss: 0.3359
# Epoch 12: val_loss did not improve from 0.33286
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 19s 137ms/step - accuracy: 0.8777 - loss: 0.3375 - val_accuracy: 0.8598 - val_loss: 0.3377 - learning_rate: 2.0000e-05
# Epoch 13/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8789 - loss: 0.3327
# Epoch 13: val_loss did not improve from 0.33286
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 19s 136ms/step - accuracy: 0.8804 - loss: 0.3303 - val_accuracy: 0.8411 - val_loss: 0.3757 - learning_rate: 2.0000e-05
# Epoch 14/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8914 - loss: 0.3141
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 14: val_loss did not improve from 0.33286
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 19s 136ms/step - accuracy: 0.8844 - loss: 0.3164 - val_accuracy: 0.8232 - val_loss: 0.4227 - learning_rate: 2.0000e-05
# Epoch 15/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8891 - loss: 0.3153
# Epoch 15: val_loss did not improve from 0.33286
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 19s 136ms/step - accuracy: 0.8897 - loss: 0.3151 - val_accuracy: 0.7911 - val_loss: 0.4444 - learning_rate: 4.0000e-06
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 8.

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.show()

# %%
test_loss, test_acc = model.evaluate(test_ds)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7781 - loss: 0.6890
# Test Loss: 0.6890
# Test Accuracy: 0.7781

# %%
y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images, verbose=0)

    y_true.extend(np.argmax(labels.numpy(), axis=1))
    y_pred.extend(np.argmax(preds, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)

print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.96      0.60      0.74       400
#   meningioma       0.69      0.58      0.63       400
#      notumor       0.70      1.00      0.82       400
#    pituitary       0.85      0.93      0.89       400
#
#     accuracy                           0.78      1600
#    macro avg       0.80      0.78      0.77      1600
# weighted avg       0.80      0.78      0.77      1600

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
model.save("custom_cnn_brain_tumor.keras")

# %%
num_classes = len(class_names)

base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(img_height, img_width, 3)
)

base_model.trainable = False

inputs = layers.Input(shape=(img_height, img_width, 3))
x = img_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)

mobilenet_model = Model(inputs, outputs, name="MobileNetV2_Transfer")

mobilenet_model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

mobilenet_model.summary()
# Out:
# /tmp/ipykernel_58/1495500365.py:3: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "MobileNetV2_Transfer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 225, 225, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ img_augmentation (Sequential)   │ (None, 225, 225, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 8, 8, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,422,468 (9.24 MB)
#  Trainable params: 164,484 (642.52 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
early_stop = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.2,
    patience=2,
    min_lr=1e-7,
    verbose=1
)

checkpoint = callbacks.ModelCheckpoint(
    "best_mobilenetv2.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

start_time = time.time()

history_mobilenet = mobilenet_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15,
    callbacks=[early_stop, reduce_lr, checkpoint]
)

mobilenet_training_time = time.time() - start_time
print(f"MobileNetV2 training time: {mobilenet_training_time:.2f} seconds")
# Out:
# Epoch 1/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5759 - loss: 1.0120
# Epoch 1: val_loss improved from None to 0.62423, saving model to best_mobilenetv2.keras
#
# Epoch 1: finished saving model to best_mobilenetv2.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - accuracy: 0.6554 - loss: 0.8289 - val_accuracy: 0.7518 - val_loss: 0.6242 - learning_rate: 0.0010
# Epoch 2/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7378 - loss: 0.6425
# Epoch 2: val_loss improved from 0.62423 to 0.54541, saving model to best_mobilenetv2.keras
#
# Epoch 2: finished saving model to best_mobilenetv2.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.7402 - loss: 0.6399 - val_accuracy: 0.7732 - val_loss: 0.5454 - learning_rate: 0.0010
# Epoch 3/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7661 - loss: 0.6061
# Epoch 3: val_loss improved from 0.54541 to 0.51272, saving model to best_mobilenetv2.keras
#
# Epoch 3: finished saving model to best_mobilenetv2.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - accuracy: 0.7647 - loss: 0.5946 - val_accuracy: 0.8152 - val_loss: 0.5127 - learning_rate: 0.0010
# Epoch 4/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7898 - loss: 0.5487
# Epoch 4: val_loss improved from 0.51272 to 0.50841, saving model to best_mobilenetv2.keras
#
# Epoch 4: finished saving model to best_mobilenetv2.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - accuracy: 0.7935 - loss: 0.5294 - val_accuracy: 0.7848 - val_loss: 0.5084 - learning_rate: 0.0010
# Epoch 5/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7781 - loss: 0.5395
# Epoch 5: val_loss improved from 0.50841 to 0.49781, saving model to best_mobilenetv2.keras
#
# Epoch 5: finished saving model to best_mobilenetv2.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.7795 - loss: 0.5301 - val_accuracy: 0.8027 - val_loss: 0.4978 - learning_rate: 0.0010
# Epoch 6/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8058 - loss: 0.5011
# Epoch 6: val_loss did not improve from 0.49781
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.8004 - loss: 0.5101 - val_accuracy: 0.7857 - val_loss: 0.5097 - learning_rate: 0.0010
# Epoch 7/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7933 - loss: 0.5061
# Epoch 7: val_loss improved from 0.49781 to 0.47546, saving model to best_mobilenetv2.keras
#
# Epoch 7: finished saving model to best_mobilenetv2.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.7984 - loss: 0.5076 - val_accuracy: 0.7893 - val_loss: 0.4755 - learning_rate: 0.0010
# Epoch 8/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8023 - loss: 0.4997
# Epoch 8: val_loss did not improve from 0.47546
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.8105 - loss: 0.4926 - val_accuracy: 0.7964 - val_loss: 0.5116 - learning_rate: 0.0010
# Epoch 9/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8066 - loss: 0.4788
# Epoch 9: val_loss improved from 0.47546 to 0.47195, saving model to best_mobilenetv2.keras
#
# Epoch 9: finished saving model to best_mobilenetv2.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.8089 - loss: 0.4733 - val_accuracy: 0.8098 - val_loss: 0.4720 - learning_rate: 0.0010
# Epoch 10/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8176 - loss: 0.4754
# Epoch 10: val_loss did not improve from 0.47195
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.8205 - loss: 0.4787 - val_accuracy: 0.7804 - val_loss: 0.4892 - learning_rate: 0.0010
# Epoch 11/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8067 - loss: 0.4885
# Epoch 11: val_loss improved from 0.47195 to 0.46238, saving model to best_mobilenetv2.keras
#
# Epoch 11: finished saving model to best_mobilenetv2.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.8109 - loss: 0.4774 - val_accuracy: 0.7821 - val_loss: 0.4624 - learning_rate: 0.0010
# Epoch 12/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8184 - loss: 0.4581
# Epoch 12: val_loss did not improve from 0.46238
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.8174 - loss: 0.4611 - val_accuracy: 0.7875 - val_loss: 0.4721 - learning_rate: 0.0010
# Epoch 13/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8168 - loss: 0.4729
# Epoch 13: val_loss improved from 0.46238 to 0.45033, saving model to best_mobilenetv2.keras
#
# Epoch 13: finished saving model to best_mobilenetv2.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.8179 - loss: 0.4586 - val_accuracy: 0.8170 - val_loss: 0.4503 - learning_rate: 0.0010
# Epoch 14/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8178 - loss: 0.4347
# Epoch 14: val_loss improved from 0.45033 to 0.42478, saving model to best_mobilenetv2.keras
#
# Epoch 14: finished saving model to best_mobilenetv2.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - accuracy: 0.8154 - loss: 0.4507 - val_accuracy: 0.8259 - val_loss: 0.4248 - learning_rate: 0.0010
# Epoch 15/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8203 - loss: 0.4470
# Epoch 15: val_loss did not improve from 0.42478
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.8179 - loss: 0.4515 - val_accuracy: 0.8161 - val_loss: 0.4292 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 14.
# MobileNetV2 training time: 166.86 seconds

# %%
base_model.trainable = True

for layer in base_model.layers[:-30]:
    layer.trainable = False

mobilenet_model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

start_time = time.time()

history_mobilenet_ft = mobilenet_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=[early_stop, reduce_lr, checkpoint]
)

mobilenet_finetune_time = time.time() - start_time
print(f"MobileNetV2 fine-tuning time: {mobilenet_finetune_time:.2f} seconds")
# Out:
# Epoch 1/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4185 - loss: 4.4112
# Epoch 1: val_loss did not improve from 0.42478
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 23s 104ms/step - accuracy: 0.5388 - loss: 2.6663 - val_accuracy: 0.6348 - val_loss: 1.1861 - learning_rate: 1.0000e-05
# Epoch 2/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7360 - loss: 0.7072
# Epoch 2: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
#
# Epoch 2: val_loss did not improve from 0.42478
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.7422 - loss: 0.6660 - val_accuracy: 0.6929 - val_loss: 0.8841 - learning_rate: 1.0000e-05
# Epoch 3/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7726 - loss: 0.5549
# Epoch 3: val_loss did not improve from 0.42478
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.7688 - loss: 0.5775 - val_accuracy: 0.7473 - val_loss: 0.6827 - learning_rate: 2.0000e-06
# Epoch 4/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7694 - loss: 0.5708
# Epoch 4: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
#
# Epoch 4: val_loss did not improve from 0.42478
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.7750 - loss: 0.5646 - val_accuracy: 0.7795 - val_loss: 0.5915 - learning_rate: 2.0000e-06
# Epoch 5/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7834 - loss: 0.5461
# Epoch 5: val_loss did not improve from 0.42478
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.7763 - loss: 0.5671 - val_accuracy: 0.8000 - val_loss: 0.5452 - learning_rate: 4.0000e-07
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 1.
# MobileNetV2 fine-tuning time: 76.83 seconds

# %%
mobilenet_model = tf.keras.models.load_model("best_mobilenetv2.keras")

mobilenet_test_loss, mobilenet_test_acc = mobilenet_model.evaluate(test_ds)

print(f"MobileNetV2 Test Loss: {mobilenet_test_loss:.4f}")
print(f"MobileNetV2 Test Accuracy: {mobilenet_test_acc:.4f}")
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.7444 - loss: 0.7711
# MobileNetV2 Test Loss: 0.7711
# MobileNetV2 Test Accuracy: 0.7444

# %%
num_classes = len(class_names)

eff_base = EfficientNetB0(
    weights="imagenet",
    include_top=False,
    input_shape=(img_height, img_width, 3)
)

eff_base.trainable = False

inputs = layers.Input(shape=(img_height, img_width, 3))
x = img_augmentation(inputs)
x = preprocess_input(x)
x = eff_base(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.35)(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)

efficientnet_model = Model(inputs, outputs, name="EfficientNetB0_Transfer")

efficientnet_model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

efficientnet_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "EfficientNetB0_Transfer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 225, 225, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ img_augmentation (Sequential)   │ (None, 225, 225, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 8, 8, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,214,055 (16.08 MB)
#  Trainable params: 164,484 (642.52 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
early_stop_eff = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True,
    verbose=1
)

reduce_lr_eff = callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.2,
    patience=2,
    min_lr=1e-7,
    verbose=1
)

checkpoint_eff = callbacks.ModelCheckpoint(
    "best_efficientnetb0.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

start_time = time.time()

history_eff = efficientnet_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15,
    callbacks=[early_stop_eff, reduce_lr_eff, checkpoint_eff]
)

efficientnet_training_time = time.time() - start_time
print(f"EfficientNetB0 training time: {efficientnet_training_time:.2f} seconds")
# Out:
# Epoch 1/15
# E0000 00:00:1784177799.491098      58 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/EfficientNetB0_Transfer_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6675 - loss: 0.7897
# Epoch 1: val_loss improved from None to 0.43976, saving model to best_efficientnetb0.keras
#
# Epoch 1: finished saving model to best_efficientnetb0.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 27s 125ms/step - accuracy: 0.7531 - loss: 0.6177 - val_accuracy: 0.8357 - val_loss: 0.4398 - learning_rate: 0.0010
# Epoch 2/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8281 - loss: 0.4418
# Epoch 2: val_loss improved from 0.43976 to 0.40622, saving model to best_efficientnetb0.keras
#
# Epoch 2: finished saving model to best_efficientnetb0.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 15s 107ms/step - accuracy: 0.8279 - loss: 0.4440 - val_accuracy: 0.8509 - val_loss: 0.4062 - learning_rate: 0.0010
# Epoch 3/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8587 - loss: 0.3825
# Epoch 3: val_loss did not improve from 0.40622
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 15s 103ms/step - accuracy: 0.8536 - loss: 0.3958 - val_accuracy: 0.8321 - val_loss: 0.4166 - learning_rate: 0.0010
# Epoch 4/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8716 - loss: 0.3539
# Epoch 4: val_loss improved from 0.40622 to 0.33035, saving model to best_efficientnetb0.keras
#
# Epoch 4: finished saving model to best_efficientnetb0.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 15s 106ms/step - accuracy: 0.8679 - loss: 0.3625 - val_accuracy: 0.8777 - val_loss: 0.3304 - learning_rate: 0.0010
# Epoch 5/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8616 - loss: 0.3566
# Epoch 5: val_loss did not improve from 0.33035
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.8650 - loss: 0.3511 - val_accuracy: 0.8714 - val_loss: 0.3469 - learning_rate: 0.0010
# Epoch 6/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8724 - loss: 0.3345
# Epoch 6: val_loss improved from 0.33035 to 0.31340, saving model to best_efficientnetb0.keras
#
# Epoch 6: finished saving model to best_efficientnetb0.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 15s 104ms/step - accuracy: 0.8746 - loss: 0.3306 - val_accuracy: 0.8830 - val_loss: 0.3134 - learning_rate: 0.0010
# Epoch 7/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8826 - loss: 0.3145
# Epoch 7: val_loss improved from 0.31340 to 0.29902, saving model to best_efficientnetb0.keras
#
# Epoch 7: finished saving model to best_efficientnetb0.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 15s 107ms/step - accuracy: 0.8788 - loss: 0.3260 - val_accuracy: 0.8938 - val_loss: 0.2990 - learning_rate: 0.0010
# Epoch 8/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8820 - loss: 0.3093
# Epoch 8: val_loss improved from 0.29902 to 0.28292, saving model to best_efficientnetb0.keras
#
# Epoch 8: finished saving model to best_efficientnetb0.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 15s 106ms/step - accuracy: 0.8813 - loss: 0.3070 - val_accuracy: 0.8884 - val_loss: 0.2829 - learning_rate: 0.0010
# Epoch 9/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8878 - loss: 0.2873
# Epoch 9: val_loss did not improve from 0.28292
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - accuracy: 0.8895 - loss: 0.2873 - val_accuracy: 0.8884 - val_loss: 0.3011 - learning_rate: 0.0010
# Epoch 10/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8722 - loss: 0.3025
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 10: val_loss did not improve from 0.28292
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - accuracy: 0.8813 - loss: 0.2959 - val_accuracy: 0.8705 - val_loss: 0.3225 - learning_rate: 0.0010
# Epoch 11/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8899 - loss: 0.2795
# Epoch 11: val_loss improved from 0.28292 to 0.26042, saving model to best_efficientnetb0.keras
#
# Epoch 11: finished saving model to best_efficientnetb0.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 15s 106ms/step - accuracy: 0.8969 - loss: 0.2725 - val_accuracy: 0.8982 - val_loss: 0.2604 - learning_rate: 2.0000e-04
# Epoch 12/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8933 - loss: 0.2609
# Epoch 12: val_loss did not improve from 0.26042
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.8917 - loss: 0.2637 - val_accuracy: 0.8938 - val_loss: 0.2774 - learning_rate: 2.0000e-04
# Epoch 13/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8970 - loss: 0.2547
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 13: val_loss did not improve from 0.26042
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.8998 - loss: 0.2567 - val_accuracy: 0.8964 - val_loss: 0.2705 - learning_rate: 2.0000e-04
# Epoch 14/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9041 - loss: 0.2396
# Epoch 14: val_loss did not improve from 0.26042
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9040 - loss: 0.2429 - val_accuracy: 0.8938 - val_loss: 0.2760 - learning_rate: 4.0000e-05
# Epoch 15/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9185 - loss: 0.2262
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 15: val_loss did not improve from 0.26042
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9127 - loss: 0.2371 - val_accuracy: 0.8938 - val_loss: 0.2746 - learning_rate: 4.0000e-05
# Restoring model weights from the end of the best epoch: 11.
# EfficientNetB0 training time: 228.88 seconds

# %%
eff_base.trainable = True

for layer in eff_base.layers[:-30]:
    layer.trainable = False

efficientnet_model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

start_time = time.time()

history_eff_ft = efficientnet_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=[early_stop_eff, reduce_lr_eff, checkpoint_eff]
)

efficientnet_finetune_time = time.time() - start_time
print(f"EfficientNetB0 fine-tuning time: {efficientnet_finetune_time:.2f} seconds")
# Out:
# Epoch 1/10
# E0000 00:00:1784178031.440349      58 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/EfficientNetB0_Transfer_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7874 - loss: 0.5533
# Epoch 1: val_loss did not improve from 0.26042
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 32s 136ms/step - accuracy: 0.7973 - loss: 0.5263 - val_accuracy: 0.8795 - val_loss: 0.3079 - learning_rate: 1.0000e-05
# Epoch 2/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8223 - loss: 0.4357
# Epoch 2: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
#
# Epoch 2: val_loss did not improve from 0.26042
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.8263 - loss: 0.4362 - val_accuracy: 0.8643 - val_loss: 0.3366 - learning_rate: 1.0000e-05
# Epoch 3/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8459 - loss: 0.3980
# Epoch 3: val_loss did not improve from 0.26042
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 17s 121ms/step - accuracy: 0.8453 - loss: 0.3922 - val_accuracy: 0.8607 - val_loss: 0.3424 - learning_rate: 2.0000e-06
# Epoch 4/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8458 - loss: 0.4008
# Epoch 4: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
#
# Epoch 4: val_loss did not improve from 0.26042
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 17s 118ms/step - accuracy: 0.8442 - loss: 0.4028 - val_accuracy: 0.8607 - val_loss: 0.3427 - learning_rate: 2.0000e-06
# Epoch 5/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8511 - loss: 0.3984
# Epoch 5: val_loss did not improve from 0.26042
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 16s 117ms/step - accuracy: 0.8471 - loss: 0.3893 - val_accuracy: 0.8625 - val_loss: 0.3420 - learning_rate: 4.0000e-07
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 1.
# EfficientNetB0 fine-tuning time: 98.69 seconds

# %%
efficientnet_model = tf.keras.models.load_model("best_efficientnetb0.keras")

eff_test_loss, eff_test_acc = efficientnet_model.evaluate(test_ds)

print(f"EfficientNetB0 Test Loss: {eff_test_loss:.4f}")
print(f"EfficientNetB0 Test Accuracy: {eff_test_acc:.4f}")
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.8525 - loss: 0.4938
# EfficientNetB0 Test Loss: 0.4938
# EfficientNetB0 Test Accuracy: 0.8525

# %% [markdown]
# MobileNetV2 achieved the best overall performance with 85% accuracy and 85% weighted F1-score.
# It outperformed the custom CNN and EfficientNetB0 while remaining lightweight, making it the most suitable model for deployment in the final application.

# %%
import json

with open("class_names.json", "w") as f:
    json.dump(class_names, f)

# %%
import os

os.listdir("/kaggle/working")
